# %% [markdown]
# # TocoPatch Detect UC
#
# Below are some of the recordings showing clear uterine contraction patterns. I'll add more recordings. Some of the recordings are causing the tool to close automatically such as August 15 pt D.
#
# ## Malawi_ctg_db
#
# - October 1, pt B
# - October 2, pt A
# - October 5, pt C - 8.9mins
#
# ## Recordings from Malawi_ctg_db_user2
#
# - August 6, pt A - 18.7 mins
# - August 6, pt A - 34.3 mins
# - August 6, pt B
# - August 8, pt C 10.3 mins 5:02:48
# - August 9, pt A - 30.3 mins
# - August 9, pt F
# - August 14 pt D (contractions at 3 - 5, 11 - 13.5, 20 - 22, 25 - 28)
# - August 15, pt A
# - August 15 pt E (contractions at 4 - 6, 9 - 11, 13 - 15 mild , 19 - 21)
# - October 4 pt A (contractions at 3 - 4.5, 6 - 8, 13 - 15.5, 17.5 - 19.5)
# - October 4 pt B (contractions at  7 - 10, 14 - 16, 20 -22)

# %% [markdown]
# # Configuration

# %% [markdown]
# ### Select PC or Mac
# usePc:
#
# - True: Uses Windows Surface Pro
# - False:  Uses Mac (Doug's  development Laptop)

# %%
usePc = False

# %% [markdown]
# ### Recording set to use
#
# use_user_2:
# - False:  Uses Malawi_ctg_db     (Monica's User 1 dataset)
# - True: Malawi_ctg_db_user2      (Monica's User 2 dataset)

# %%
use_user_2 = True

# %% [markdown]
# ###### Apply configuration to paths (update only if paths change)

# %%
if usePc:
    if use_user_2:
        path = 'c:\Users\Dtree\Documents\ctg_db'
    else:
        path = 'c:\Users\Dtree\Documents\ctg_db'
else:
    if use_user_2:
        path = '/Users/doug/Documents/GitHub/Malawi_ctg_db_user2'
    else:
        path = '/Users/doug/Documents/GitHub/Malawi_ctg_db'

# %% [markdown]
# ###### Apply configuration to source code directory  (update only if paths change)

# %%
import sys
if usePc:
    sys.path.append('c:\Users\Dtree\Documents\GitHub\CTG\CombinedRecorder')
else:
    sys.path.append('/Users/doug/Documents/GitHub/LowCostCTG/CombinedRecorder')

# %% [markdown]
# # Selected Recordings

# %% [markdown]
# ### Definitions for Malawi_ctg_db

# %%
SelectedRecordings1 = {
    # October 1, pt B
    '56f7347d-dd4c-4839-a386-e1d3a8966fd7':
        ['453c1a42-3135-4750-b0b7-7af96da035cf'],
    # October 2, pt A
    'e4e29966-ee72-4bf1-b32e-05232fa50936':
        ['5a3ec7c4-ea90-40dd-a222-8d0758b78276'],
    # October 5, pt C - 8.9mins
    'f65f75a5-2c68-4bd0-9f85-2d2fbc5b5db5':
        ['c0a0c86c-e059-4383-94ee-ec0ee9fa52d6'],
}

# %% [markdown]
# ### Definitions for Malawi_ctg_db_user2

# %%
SelectedRecordings2 = {
    # August 6, pt A - 18.7 mins
    '05de685b-e73e-4ada-9a49-b29aa81a4d37':
        ['b03cea74-32b9-4135-afda-b1dac1fe03f6'],
    
    # August 6, pt A - 34.3 mins
    '05de685b-e73e-4ada-9a49-b29aa81a4d37':
         ['bbe8443e-90f2-4c6f-88ae-93b0789fdba7'],
    
    # August 6, pt B
    '7eb554ab-fc04-460b-b388-8bfbe1a387fc':
        ['7eb554ab-fc04-460b-b388-8bfbe1a387fc'],
    
    # August 8, pt C 10.3 mins 5:02:48
    '57ba7581-81d0-4601-b884-9139fcd98890':
        ['3cef2dd2-96af-4af4-a816-7cd92841a880'],
    
    # August 9, pt A - 30.3 mins
    '906d2e3f-e391-4cbf-a324-4afdfd917574':
        ['668a744e-65a0-49b5-abd9-ede5741f48df'],
    
    # August 9, pt F
    '3331a782-3057-401c-9c6a-2e0feb7abef2':
        ['d2b5181b-8f79-4b5d-b7c6-1783510ff643'],
    
    # August 14 pt D
    '0e01d1dd-c60b-4a0b-b1f7-4b4bb0a6adb4':
        ['54976ba0-228e-435a-8d28-9265984d1379'],
    
    # August 15, pt A
    '091a24e2-e069-4b01-a11c-e534c8cd29ab':
       ['c74e5801-59dc-4a38-b86f-fcb603f2a04f'],
    
    # August 15 pt E
    '5fce3c21-9375-4f5c-b249-875fac0fd6d8':
        ['ddcc6b5b-4933-48a2-9bbd-241e21aeaa40'],
    
    # October 4 pt A
    '6e688613-e966-458b-8583-5055b2f98634':
        ['3761b754-70d2-4a47-a897-3519daa4632f'],
    
    # October 4 pt B
    '135da2bb-0d36-4810-b3f8-ffbc76a43fcf':
        ['ab0fb7c2-dee1-48d6-ba48-2faf23f116b3'],
    }

# %% [markdown]
# ###### Select which set of recording to use based on confguration

# %%
if use_user_2:
    SelectedRecordings = SelectedRecordings2
else:
    SelectedRecordings = SelectedRecordings1

# %% [markdown]
# # Imports

# %%
from display_selected_uc_recordings import showAnnotatedPlot, showAllContractions

# %%
from libFilterUC import PARAMS_FILTER_UC

# %% [markdown]
# # Default Settings for UC Filter

# %%
PARAMS_FILTER_UC
# Out:
# {'maxWidth': 78.0,
#  'minThresh': None,
#  'minWidth': 35,
#  'squelchFactor': 4,
#  'squelchPercentile': 20}

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Show filtered decels
#
# Filter parameters include:
# - squelchPercentile:  Signal percentile value used as noise threshold (0-100) [dashed ble lne]
# - squelchFactor:  Multiple of noise threshold used to define mininum maagnitude for UC Acme [cashed red line]
# - minThresh: User specified minimum magnitude (None means no absolution threshold)
# - minWidth: minimum width of contraction (as measured from half of peak magnitude)
# - maxWidth: Maximum width of contraction

# %%
showAllContractions(SelectedRecordings, path,
                    squelchFactor=4, 
                    squelchPercentile=20,
                    minThresh=None, 
                    minWidth=35, 
                    maxWidth=60*1.3,    # sustained contraction
                    verbose=False)
# Out:
# kwargs: {'minWidth': 35, 'verbose': False, 'maxWidth': 78.0}
# ----------------------------------------
# august 14, 2018 -- pt d :
# 0e01d1dd-c60b-4a0b-b1f7-4b4bb0a6adb4/54976ba0-228e-435a-8d28-9265984d1379.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.6   0.3-13.8   width:  810 mag: 5.88
# uc @  2.7   2.1- 3.1   width:   58 mag: 16.71
# uc @  4.1   3.7- 4.7   width:   63 mag: 107.94
# uc @  6.4   5.8- 6.9   width:   65 mag: 17.16
# uc @  8.2   5.7- 9.6   width:  232 mag: 15.16
# uc @ 10.4   9.9-10.8   width:   56 mag: 21.72
# uc @ 12.9  11.4-13.3   width:  110 mag: 129.06
# uc @ 14.3  13.9-21.8   width:  476 mag: 8.87
# uc @ 16.0  13.9-21.9   width:  479 mag: 7.76
# uc @ 17.9  15.5-21.8   width:  379 mag: 10.16
# uc @ 19.2  18.8-19.6   width:   50 mag: 32.98
# uc @ 20.6  20.2-21.3   width:   71 mag: 112.62
# uc @ 22.7  22.3-23.2   width:   52 mag: 9.24
# uc @ 24.0  23.6-24.3   width:   39 mag: 26.02
# uc @ 25.3  24.9-26.0   width:   66 mag: 41.73
# uc @ 26.9  26.4-27.6   width:   70 mag: 40.03
# uc @ 29.2  22.2-30.9   width:  518 mag: 5.73
# uc @ 30.6  24.6-30.9   width:  375 mag: 7.65
#
# WARNING: Sustained Contraction(s):
#     sustained uc @ 12.9m  width: 110 sec
#
# Final:
# uc @  4.1   3.7- 4.7   width:   63 mag: 107.94
# uc @ 12.9  11.4-13.3   width:  110 mag: 129.06
# uc @ 19.2  18.8-19.6   width:   50 mag: 32.98
# uc @ 20.6  20.2-21.3   width:   71 mag: 112.62
# uc @ 24.0  23.6-24.3   width:   39 mag: 26.02
# uc @ 25.3  24.9-26.0   width:   66 mag: 41.73
#
# sustainedUC:
# [{'idxAcme': 1521,
#   'mag': 129.06132336917096,
#   'tAcme': 12.853729125721618,
#   'tLeft': 11.445066342397272,
#   'tRight': 13.28135889923079,
#   'width': 110.17755341001109}]
# ****************************************
#
# ----------------------------------------
# august 6, 2018 -- pt a :
# 05de685b-e73e-4ada-9a49-b29aa81a4d37/bbe8443e-90f2-4c6f-88ae-93b0789fdba7.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  1.0   0.6- 1.4   width:   50 mag: 17.97
# uc @  3.5   0.4- 3.9   width:  211 mag: 11.40
# uc @  4.8   4.4- 5.1   width:   46 mag: 46.27
# uc @  6.3   5.8- 6.9   width:   67 mag: 116.80
# uc @  8.1   4.2- 8.8   width:  276 mag: 16.20
# uc @  9.8   9.4-10.3   width:   52 mag: 44.59
# uc @ 11.8  11.4-21.9   width:  632 mag: 55.14
# uc @ 13.3  12.5-14.3   width:  109 mag: 144.80
# uc @ 15.2  11.5-21.7   width:  617 mag: 68.25
# uc @ 17.2  16.6-17.8   width:   67 mag: 166.32
# uc @ 20.5  20.1-21.4   width:   81 mag: 85.10
# uc @ 23.5  22.8-34.2   width:  688 mag: 9.34
# uc @ 26.0  25.7-26.4   width:   43 mag: 71.45
# uc @ 27.8  27.1-28.4   width:   76 mag: 88.01
# uc @ 29.0  26.9-29.5   width:  155 mag: 37.39
# uc @ 33.4  33.1-33.9   width:   50 mag: 79.39
#
# WARNING: Sustained Contraction(s):
#     sustained uc @ 13.3m  width: 109 sec
#     sustained uc @ 20.5m  width: 81 sec
#
# Final:
# uc @  4.8   4.4- 5.1   width:   46 mag: 46.27
# uc @  6.3   5.8- 6.9   width:   67 mag: 116.80
# uc @  9.8   9.4-10.3   width:   52 mag: 44.59
# uc @ 13.3  12.5-14.3   width:  109 mag: 144.80
# uc @ 17.2  16.6-17.8   width:   67 mag: 166.32
# uc @ 20.5  20.1-21.4   width:   81 mag: 85.10
# uc @ 26.0  25.7-26.4   width:   43 mag: 71.45
# uc @ 27.8  27.1-28.4   width:   76 mag: 88.01
# uc @ 33.4  33.1-33.9   width:   50 mag: 79.39
#
# sustainedUC:
# [{'idxAcme': 1572,
#   'mag': 144.79895893171968,
#   'tAcme': 13.264509967821647,
#   'tLeft': 12.460499180807947,
#   'tRight': 14.269523451588771,
#   'width': 108.54145624684946},
#  {'idxAcme': 2441,
#   'mag': 85.09793094459317,
#   'tAcme': 20.542482612768577,
#   'tLeft': 20.098601657438095,
#   'tRight': 21.44699474815899,
#   'width': 80.90358544325362}]
# ****************************************
#
# ----------------------------------------
# august 15 2018 -- pt e :
# 5fce3c21-9375-4f5c-b249-875fac0fd6d8/ddcc6b5b-4933-48a2-9bbd-241e21aeaa40.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.3   0.1- 0.6   width:   33 mag: 82.59
# uc @  4.6   4.0- 6.1   width:  128 mag: 112.74
# uc @  6.8   3.2-11.9   width:  525 mag: 45.55
# uc @  9.5   8.2-10.7   width:  147 mag: 111.36
# uc @ 11.5   3.2-11.9   width:  525 mag: 46.55
# uc @ 14.9  13.7-15.2   width:   88 mag: 41.10
# uc @ 17.3  16.8-17.6   width:   48 mag: 5.76
# uc @ 18.6  18.2-22.5   width:  257 mag: 53.60
# uc @ 21.0  19.1-22.3   width:  190 mag: 116.01
# uc @ 24.3  23.8-24.8   width:   65 mag: 97.17
# uc @ 27.5  27.1-28.0   width:   52 mag: 8.77
#
# WARNING: Sustained Contraction(s):
#     sustained uc @  4.6m  width: 128 sec
#     sustained uc @  9.5m  width: 147 sec
#     sustained uc @ 14.9m  width: 88 sec
#     sustained uc @ 21.0m  width: 190 sec
#
# Final:
# uc @  4.6   4.0- 6.1   width:  128 mag: 112.74
# uc @  9.5   8.2-10.7   width:  147 mag: 111.36
# uc @ 21.0  19.1-22.3   width:  190 mag: 116.01
# uc @ 24.3  23.8-24.8   width:   65 mag: 97.17
#
# sustainedUC:
# [{'idxAcme': 557,
#   'mag': 112.74316632453962,
#   'tAcme': 4.630293074229541,
#   'tLeft': 3.9553401313986813,
#   'tRight': 6.096857493220048,
#   'width': 128.491041709282},
#  {'idxAcme': 1141,
#   'mag': 111.35810803699663,
#   'tAcme': 9.496620464516225,
#   'tLeft': 8.238374855041416,
#   'tRight': 10.688204054946015,
#   'width': 146.98975199427593},
#  {'idxAcme': 1784,
#   'mag': 41.09663785891779,
#   'tAcme': 14.854580245259957,
#   'tLeft': 13.746324178636447,
#   'tRight': 15.212888597626955,
#   'width': 87.99386513943048},
#  {'idxAcme': 2523,
#   'mag': 116.00791152102349,
#   'tAcme': 21.012484254543963,
#   'tLeft': 19.079285702238295,
#   'tRight': 22.25406435925752,
#   'width': 190.48671942115348}]
# ****************************************
#
# ----------------------------------------
# october 4, 2018 -- pt b :
# 135da2bb-0d36-4810-b3f8-ffbc76a43fcf/ab0fb7c2-dee1-48d6-ba48-2faf23f116b3.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.5   0.1-22.8   width: 1363 mag: 2.80
# uc @  1.9   0.1-22.8   width: 1366 mag: 2.04
# uc @  3.9   1.3-22.8   width: 1292 mag: 3.34
# uc @  6.2   2.9-11.1   width:  492 mag: 3.69
# uc @  7.6   7.1- 8.4   width:   76 mag: 41.02
# uc @  9.1   7.0- 9.7   width:  166 mag: 22.12
# uc @ 10.4   6.8-10.8   width:  242 mag: 8.71
# uc @ 12.0  11.3-22.8   width:  689 mag: 4.64
# uc @ 14.7  14.0-15.7   width:   97 mag: 32.34
# uc @ 16.2  13.6-16.8   width:  194 mag: 14.74
# uc @ 18.7  17.9-19.2   width:   74 mag: 16.77
# uc @ 22.2  20.9-22.8   width:  116 mag: 73.46
#
# WARNING: Sustained Contraction(s):
#     sustained uc @ 14.7m  width: 97 sec
#     sustained uc @ 22.2m  width: 116 sec
#
# Final:
# uc @  7.6   7.1- 8.4   width:   76 mag: 41.02
# uc @ 14.7  14.0-15.7   width:   97 mag: 32.34
# uc @ 18.7  17.9-19.2   width:   74 mag: 16.77
# uc @ 22.2  20.9-22.8   width:  116 mag: 73.46
#
# sustainedUC:
# [{'idxAcme': 1769,
#   'mag': 32.33713871975246,
#   'tAcme': 14.741666666666667,
#   'tLeft': 14.033333333333333,
#   'tRight': 15.65,
#   'width': 97.00000000000003},
#  {'idxAcme': 2663,
#   'mag': 73.45703784178473,
#   'tAcme': 22.191666666666666,
#   'tLeft': 20.9,
#   'tRight': 22.833333333333332,
#   'width': 116.00000000000001}]
# ****************************************
#
# ----------------------------------------
# august 9, 2018 -- pt f :
# 3331a782-3057-401c-9c6a-2e0feb7abef2/d2b5181b-8f79-4b5d-b7c6-1783510ff643.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.7   0.4- 1.1   width:   44 mag: 20.84
# uc @  3.1   2.2- 3.9   width:  102 mag: 21.83
# uc @  5.0   4.6- 5.4   width:   51 mag: 10.88
# uc @  6.3   4.4-11.3   width:  414 mag: 8.28
# uc @  9.3   8.7-10.7   width:  118 mag: 13.81
# uc @ 13.5  12.4-15.6   width:  189 mag: 9.71
# uc @ 15.0  14.5-15.4   width:   51 mag: 16.30
# uc @ 17.6   0.1-21.2   width: 1263 mag: 5.26
# uc @ 20.8  20.0-21.2   width:   71 mag: 9.53
#
# WARNING: Sustained Contraction(s):
#     sustained uc @  3.1m  width: 102 sec
#     sustained uc @  9.3m  width: 118 sec
#
# Final:
# uc @  0.7   0.4- 1.1   width:   44 mag: 20.84
# uc @  3.1   2.2- 3.9   width:  102 mag: 21.83
#
# sustainedUC:
# [{'idxAcme': 375,
#   'mag': 21.82961962340334,
#   'tAcme': 3.070479409718046,
#   'tLeft': 2.245537644956626,
#   'tRight': 3.9454176450710667,
#   'width': 101.99280000686645},
#  {'idxAcme': 1123,
#   'mag': 13.810472154622849,
#   'tAcme': 9.303372743470995,
#   'tLeft': 8.736746076766183,
#   'tRight': 10.703273920035828,
#   'width': 117.99167059617872}]
# ****************************************
#
# ----------------------------------------
# october 4, 2018 -- pt a :
# 6e688613-e966-458b-8583-5055b2f98634/3761b754-70d2-4a47-a897-3519daa4632f.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.3   0.0- 0.9   width:   49 mag: 5.56
# uc @  3.8   3.2- 4.2   width:   64 mag: 80.61
# uc @  5.2   4.7- 8.8   width:  247 mag: 51.50
# uc @  6.8   5.8- 8.5   width:  160 mag: 101.09
# uc @  8.2   4.8- 8.7   width:  230 mag: 70.42
# uc @ 14.3  13.8-15.6   width:  103 mag: 119.80
# uc @ 17.4  17.0-25.6   width:  518 mag: 51.33
# uc @ 20.3  18.3-22.1   width:  231 mag: 99.16
# uc @ 21.6  18.0-23.7   width:  344 mag: 76.34
# uc @ 22.9  18.1-23.6   width:  326 mag: 86.72
# uc @ 25.0  24.5-25.5   width:   58 mag: 89.02
# uc @ 27.4  26.9-28.1   width:   71 mag: 105.58
#
# WARNING: Sustained Contraction(s):
#     sustained uc @  6.8m  width: 160 sec
#     sustained uc @ 14.3m  width: 103 sec
#     sustained uc @ 20.3m  width: 231 sec
#
# Final:
# uc @  3.8   3.2- 4.2   width:   64 mag: 80.61
# uc @  6.8   5.8- 8.5   width:  160 mag: 101.09
# uc @ 14.3  13.8-15.6   width:  103 mag: 119.80
# uc @ 20.3  18.3-22.1   width:  231 mag: 99.16
# uc @ 25.0  24.5-25.5   width:   58 mag: 89.02
# uc @ 27.4  26.9-28.1   width:   71 mag: 105.58
#
# sustainedUC:
# [{'idxAcme': 804,
#   'mag': 101.0864361341386,
#   'tAcme': 6.7739955293925345,
#   'tLeft': 5.8486078274728515,
#   'tRight': 8.514403592635972,
#   'width': 159.94774590978724},
#  {'idxAcme': 1696,
#   'mag': 119.79970945531971,
#   'tAcme': 14.346893053359107,
#   'tLeft': 13.83750532753176,
#   'tRight': 15.560933799914288,
#   'width': 103.40570834295167},
#  {'idxAcme': 2398,
#   'mag': 99.16082323085196,
#   'tAcme': 20.30672944553908,
#   'tLeft': 18.269178542229685,
#   'tRight': 22.115055872226165,
#   'width': 230.75263979978877}]
# ****************************************
#
# ----------------------------------------
# august 9, 2018 -- pt a :
# 906d2e3f-e391-4cbf-a324-4afdfd917574/668a744e-65a0-49b5-abd9-ede5741f48df.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.7   0.3- 1.1   width:   49 mag: 6.83
# uc @  5.4   0.1- 5.8   width:  343 mag: 2.02
# uc @  6.7   6.3- 7.2   width:   52 mag: 10.70
# uc @  8.1   6.2- 9.6   width:  209 mag: 4.26
# uc @ 10.8  10.2-11.5   width:   75 mag: 4.33
# uc @ 12.7   6.1-30.0   width: 1433 mag: 2.30
# uc @ 14.5   6.1-29.9   width: 1429 mag: 2.67
# uc @ 16.4   6.1-30.0   width: 1434 mag: 2.19
# uc @ 18.0   6.1-29.9   width: 1427 mag: 2.89
# uc @ 21.2   6.1-29.9   width: 1428 mag: 2.76
# uc @ 22.7  17.2-29.9   width:  761 mag: 3.32
# uc @ 23.9  23.5-24.9   width:   85 mag: 4.85
# uc @ 25.9   6.1-29.9   width: 1429 mag: 2.67
# uc @ 27.2   6.1-29.9   width: 1427 mag: 2.82
# uc @ 29.2  28.8-29.6   width:   49 mag: 8.22
#
# WARNING: Sustained Contraction(s):
#     sustained uc @ 23.9m  width: 85 sec
#
# Final:
# uc @  6.7   6.3- 7.2   width:   52 mag: 10.70
# uc @ 29.2  28.8-29.6   width:   49 mag: 8.22
#
# sustainedUC:
# [{'idxAcme': 2881,
#   'mag': 4.851675593945715,
#   'tAcme': 23.93622897890432,
#   'tLeft': 23.452945727433526,
#   'tRight': 24.86946560243414,
#   'width': 84.9911925000368}]
# ****************************************
#
# ----------------------------------------
# august 8, 2018 -- pt c :
# 57ba7581-81d0-4601-b884-9139fcd98890/3cef2dd2-96af-4af4-a816-7cd92841a880.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.3   0.1- 0.7   width:   34 mag: 37.42
# uc @  2.2   1.8- 2.6   width:   51 mag: 74.99
# uc @  4.4   4.0- 4.8   width:   50 mag: 62.00
# uc @  6.9   6.4- 7.3   width:   56 mag: 76.32
# uc @  8.2   7.8- 8.5   width:   46 mag: 46.07
# uc @  9.4   9.0-10.3   width:   76 mag: 23.55
#
#
# Final:
# uc @  2.2   1.8- 2.6   width:   51 mag: 74.99
# uc @  4.4   4.0- 4.8   width:   50 mag: 62.00
# uc @  6.9   6.4- 7.3   width:   56 mag: 76.32
#
# sustainedUC:
# []
# ****************************************
#
# ----------------------------------------
# august 15, 2018 -- pt a :
# 091a24e2-e069-4b01-a11c-e534c8cd29ab/c74e5801-59dc-4a38-b86f-fcb603f2a04f.p
# ['pos', 'raw', 'uc', 'filtered', 'posMin', 'alt_uc']
# sustainedUC:
# []
# Filtering on spacing and magnitude
# Initial:
# uc @  0.6   0.3-30.3   width: 1800 mag: 4.58
# uc @  4.2   3.8- 5.3   width:   87 mag: 11.92
# uc @  6.1   0.3-13.3   width:  785 mag: 4.87
# uc @  7.5   7.1- 8.6   width:   88 mag: 19.44
# uc @ 10.8   0.2-30.3   width: 1800 mag: 4.53
# uc @ 12.1  11.7-12.9   width:   75 mag: 10.07
# uc @ 15.0   0.3-30.3   width: 1800 mag: 4.61
# uc @ 17.8  17.3-18.9   width:   95 mag: 17.66
# uc @ 20.4   0.2-30.3   width: 1801 mag: 4.12
# uc @ 23.9  22.7-24.4   width:   99 mag: 7.41
# uc @ 27.4  25.8-29.3   width:  213 mag: 7.75
# uc @ 28.7  26.6-29.2   width:  155 mag: 9.72
#
# WARNING: Sustained Contraction(s):
#     sustained uc @  4.2m  width: 87 sec
#     sustained uc @  7.5m  width: 88 sec
#     sustained uc @ 17.8m  width: 95 sec
#     sustained uc @ 23.9m  width: 99 sec
#     sustained uc @ 28.7m  width: 155 sec
#
# Final:
# uc @  7.5   7.1- 8.6   width:   88 mag: 19.44
# uc @ 17.8  17.3-18.9   width:   95 mag: 17.66
#
# sustainedUC:
# [{'idxAcme': 495,
#   'mag': 11.92423162484553,
#   'tAcme': 4.218662945545593,
#   'tLeft': 3.7936736318396687,
#   'tRight': 5.251970296516861,
#   'width': 87.49779988063153},
#  {'idxAcme': 891,
#   'mag': 19.43945206382147,
#   'tAcme': 7.518579969615124,
#   'tLeft': 7.118590027303666,
#   'tRight': 8.593552939577169,
#   'width': 88.49777473641015},
#  {'idxAcme': 2121,
#   'mag': 17.65512501437586,
#   'tAcme': 17.768322241346244,
#   'tLeft': 17.32666668004401,
#   'tRight': 18.918293325491685,
#   'width': 95.49759872686053},
#  {'idxAcme': 2857,
#   'mag': 7.405544309188785,
#   'tAcme': 23.901501356788607,
#   'tLeft': 22.693198406056073,
#   'tRight': 24.351490041888997,
#   'width': 99.49749814997546},
#  {'idxAcme': 3438,
#   'mag': 9.715847629422237,
#   'tAcme': 28.743046283516883,
#   'tLeft': 26.609766591189103,
#   'tRight': 29.193034968617273,
#   'width': 154.99610264569014}]
# ****************************************
